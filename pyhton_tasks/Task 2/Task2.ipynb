# %%
import pandas as pd
import numpy as np
import json
import re
from decimal import Decimal

# %%
# records = [json.loads(line) for line in open('usa.gov_click_data_3.json')]

# initial_frame = pd.DataFrame(records)

# initial_frame.drop(['_heartbeat_','kw'], axis = 1,inplace = True)
# initial_frame.head(15)

# %%
records = []
with open('usa.gov_click_data_1.json') as f:
    for line in f:
        lineDict = json.loads(line)
        if '_heartbeat_' in lineDict.keys() or 'kw' in lineDict.keys():
            lineDict['_heartbeat_'] = np.nan
            lineDict['kw'] = np.nan
            
        records.append(lineDict)

initial_frame = pd.DataFrame(records)
initial_frame.head(14)
# Out:
#                                                     a     c  nk  \
# 0   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...    US   1
# 1                              GoogleMaps/RochesterNY    US   0
# 2   Mozilla/4.0 (Windows NT 6.1; MSIE 8.0; Windows...    US   1
# 3   Mozilla/5.0 (Macintosh; Intel Mac OS X 10_6_8)...    BR   0
# 4   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...    US   0
# 5   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...    US   0
# 6   Mozilla/5.0 (Windows NT 5.1) AppleWebKit/535.1...    PL   0
# 7   Mozilla/5.0 (Windows NT 6.1; rv:2.0.1) Gecko/2...  None   0
# 8   Opera/9.80 (Ubuntu 14.04.6; Linux zbov; U; en)...  None   0
# 9   Mozilla/5.0 (Windows NT 6.1; WOW64) AppleWebKi...  None   0
# 10  Mozilla/5.0 (Windows NT 6.1; WOW64; rv:10.0.2)...    US   1
# 11  Mozilla/5.0 (Macintosh; U; Intel Mac OS X 10.4...    US   0
#
#                      tz   gr       g       h             l  \
# 0      America/New_York   MA  A6qOVH  wfLQtf       orofrog
# ...

# %%
initial_frame.dropna(axis=1,inplace=True,how='all')

# %%
initial_frame.dropna(axis=0,inplace=True,how='all')

# %%
column_names = ['web_browser','operating_sys','from_url','to_url','city','longitude','latitude','time_zone','time_in','time_out']
prepare_frame = pd.DataFrame(columns = column_names)

# %%
prepare_frame['web_browser'] = pd.Series([x.split()[0] for x in initial_frame['a'].values])
prepare_frame.head()
# Out:
#               web_browser operating_sys from_url to_url city longitude  \
# 0             Mozilla/5.0           NaN      NaN    NaN  NaN       NaN
# 1  GoogleMaps/RochesterNY           NaN      NaN    NaN  NaN       NaN
# 2             Mozilla/4.0           NaN      NaN    NaN  NaN       NaN
# 3             Mozilla/5.0           NaN      NaN    NaN  NaN       NaN
# 4             Mozilla/5.0           NaN      NaN    NaN  NaN       NaN
#
#   latitude time_zone time_in time_out
# 0      NaN       NaN     NaN      NaN
# 1      NaN       NaN     NaN      NaN
# 2      NaN       NaN     NaN      NaN
# 3      NaN       NaN     NaN      NaN
# 4      NaN       NaN     NaN      NaN

# %%
def extract_os(s):
    word = re.search(r"\((.*?)\)*;|\((.*?)\)", str(s))
    if word:
        return word.group(0).replace("(", "").replace(";", "").replace(")","")
    else:
        return None
prepare_frame['operating_sys'] = initial_frame['a'].apply(extract_os)
prepare_frame.head()
# Out:
#               web_browser   operating_sys from_url to_url city longitude  \
# 0             Mozilla/5.0  Windows NT 6.1      NaN    NaN  NaN       NaN
# 1  GoogleMaps/RochesterNY            None      NaN    NaN  NaN       NaN
# 2             Mozilla/4.0  Windows NT 6.1      NaN    NaN  NaN       NaN
# 3             Mozilla/5.0       Macintosh      NaN    NaN  NaN       NaN
# 4             Mozilla/5.0  Windows NT 6.1      NaN    NaN  NaN       NaN
#
#   latitude time_zone time_in time_out
# 0      NaN       NaN     NaN      NaN
# 1      NaN       NaN     NaN      NaN
# 2      NaN       NaN     NaN      NaN
# 3      NaN       NaN     NaN      NaN
# 4      NaN       NaN     NaN      NaN

# %%
def extract_url(s):
    if s is np.nan:
        return None
    else:
        word = s.split("//")[-1].split("/")[0]
        return word
    
prepare_frame['from_url'] = initial_frame['r'].apply(extract_url)
prepare_frame['to_url'] = initial_frame['u'].apply(extract_url)
prepare_frame.head()
# Out:
#               web_browser   operating_sys               from_url  \
# 0             Mozilla/5.0  Windows NT 6.1       www.facebook.com
# 1  GoogleMaps/RochesterNY            None       www.AwareMap.com
# 2             Mozilla/4.0  Windows NT 6.1                   t.co
# 3             Mozilla/5.0       Macintosh                 direct
# 4             Mozilla/5.0  Windows NT 6.1  www.shrewsbury-ma.gov
#
#                   to_url city longitude latitude time_zone time_in time_out
# 0   www.ncbi.nlm.nih.gov  NaN       NaN      NaN       NaN     NaN      NaN
# 1   www.monroecounty.gov  NaN       NaN      NaN       NaN     NaN      NaN
# 2       boxer.senate.gov  NaN       NaN      NaN       NaN     NaN      NaN
# 3          apod.nasa.gov  NaN       NaN      NaN       NaN     NaN      NaN
# 4  www.shrewsbury-ma.gov  NaN       NaN      NaN       NaN     NaN      NaN

# %%
prepare_frame['city'] = initial_frame['cy']
prepare_frame.head()
# Out:
#               web_browser   operating_sys               from_url  \
# 0             Mozilla/5.0  Windows NT 6.1       www.facebook.com
# 1  GoogleMaps/RochesterNY            None       www.AwareMap.com
# 2             Mozilla/4.0  Windows NT 6.1                   t.co
# 3             Mozilla/5.0       Macintosh                 direct
# 4             Mozilla/5.0  Windows NT 6.1  www.shrewsbury-ma.gov
#
#                   to_url        city longitude latitude time_zone time_in  \
# 0   www.ncbi.nlm.nih.gov     Danvers       NaN      NaN       NaN     NaN
# 1   www.monroecounty.gov       Provo       NaN      NaN       NaN     NaN
# 2       boxer.senate.gov  Washington       NaN      NaN       NaN     NaN
# 3          apod.nasa.gov        Braz       NaN      NaN       NaN     NaN
# 4  www.shrewsbury-ma.gov  Shrewsbury       NaN      NaN       NaN     NaN
#
#   time_out
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
def extract_long(s):
    word = re.search(r"[^[]*\[([^]]*)\]", str(s))
    if word:
        return Decimal(word.group(1).split(',')[0].strip(' '))
    else:
        return None

prepare_frame['longitude'] = initial_frame['ll'].apply(extract_long)
prepare_frame.head()
# Out:
#               web_browser   operating_sys               from_url  \
# 0             Mozilla/5.0  Windows NT 6.1       www.facebook.com
# 1  GoogleMaps/RochesterNY            None       www.AwareMap.com
# 2             Mozilla/4.0  Windows NT 6.1                   t.co
# 3             Mozilla/5.0       Macintosh                 direct
# 4             Mozilla/5.0  Windows NT 6.1  www.shrewsbury-ma.gov
#
#                   to_url        city   longitude latitude time_zone time_in  \
# 0   www.ncbi.nlm.nih.gov     Danvers   42.576698      NaN       NaN     NaN
# 1   www.monroecounty.gov       Provo   40.218102      NaN       NaN     NaN
# 2       boxer.senate.gov  Washington     38.9007      NaN       NaN     NaN
# 3          apod.nasa.gov        Braz  -23.549999      NaN       NaN     NaN
# 4  www.shrewsbury-ma.gov  Shrewsbury   42.286499      NaN       NaN     NaN
#
#   time_out
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN

# %%
def extract_lat(s):
    word = re.search(r"[^[]*\[([^]]*)\]", str(s))
    if word:
        return Decimal(word.group(1).split(',')[-1].strip(' '))
    else:
        return None

prepare_frame['latitude'] = initial_frame['ll'].apply(extract_lat)
prepare_frame.head()
# Out:
#               web_browser   operating_sys               from_url  \
# 0             Mozilla/5.0  Windows NT 6.1       www.facebook.com
# 1  GoogleMaps/RochesterNY            None       www.AwareMap.com
# 2             Mozilla/4.0  Windows NT 6.1                   t.co
# 3             Mozilla/5.0       Macintosh                 direct
# 4             Mozilla/5.0  Windows NT 6.1  www.shrewsbury-ma.gov
#
#                   to_url        city   longitude     latitude time_zone  \
# 0   www.ncbi.nlm.nih.gov     Danvers   42.576698   -70.954903       NaN
# 1   www.monroecounty.gov       Provo   40.218102  -111.613297       NaN
# 2       boxer.senate.gov  Washington     38.9007   -77.043098       NaN
# 3          apod.nasa.gov        Braz  -23.549999   -46.616699       NaN
# 4  www.shrewsbury-ma.gov  Shrewsbury   42.286499   -71.714699       NaN
#
#   time_in time_out
# 0     NaN      NaN
# 1     NaN      NaN
# 2     NaN      NaN
# 3     NaN      NaN
# 4     NaN      NaN

# %%
# initial_frame.head(5)

# %%
prepare_frame['time_zone'] = initial_frame['tz'].apply(lambda x : None if x == "" else x)
prepare_frame['time_in'] = initial_frame['t'].values
prepare_frame['time_out'] = initial_frame['hc'].values

# %%
prepare_frame.dropna(subset=['from_url', 'to_url'],how='all',inplace=True)
prepare_frame.dropna(subset=['city', 'longitude','latitude','time_zone'],how='all',inplace=True)
prepare_frame.dropna(subset=['operating_sys'],inplace=True)
prepare_frame.isnull().sum()
# Out:
# web_browser      0
# operating_sys    0
# from_url         0
# to_url           0
# city             0
# longitude        0
# latitude         0
# time_zone        0
# time_in          0
# time_out         0
# dtype: int64

# %%
len(prepare_frame.index)
# Out:
# 8

# %%
time_in = []
time_out = []
for i, row in prepare_frame.iterrows():
    stamp_in = pd.to_datetime(row['time_in'], unit = 's').tz_localize(row['time_zone']).tz_convert('UTC')
    stamp_out = pd.to_datetime(row['time_out'], unit = 's').tz_localize(row['time_zone']).tz_convert('UTC')

    time_in.append(stamp_in)
    time_out.append(stamp_out)
    
prepare_frame['time_in'] = time_in
prepare_frame['time_out'] = time_out

prepare_frame.head(12)
# Out:
#     web_browser   operating_sys               from_url                 to_url  \
# 0   Mozilla/5.0  Windows NT 6.1       www.facebook.com   www.ncbi.nlm.nih.gov
# 2   Mozilla/4.0  Windows NT 6.1                   t.co       boxer.senate.gov
# 3   Mozilla/5.0       Macintosh                 direct          apod.nasa.gov
# 4   Mozilla/5.0  Windows NT 6.1  www.shrewsbury-ma.gov  www.shrewsbury-ma.gov
# 5   Mozilla/5.0  Windows NT 6.1  www.shrewsbury-ma.gov  www.shrewsbury-ma.gov
# 6   Mozilla/5.0  Windows NT 5.1    plus.url.google.com           www.nasa.gov
# 10  Mozilla/5.0  Windows NT 6.1                 direct         www.nysdot.gov
# 11  Mozilla/5.0       Macintosh                   t.co    oversight.house.gov
#
#           city   longitude     latitude            time_zone  \
# 0      Danvers   42.576698   -70.954903     America/New_York
# 2   Washington     38.9007   -77.043098     America/New_York
# 3         Braz  -23.549999   -46.616699    America/Sao_Paulo
# ...

# %%
 prepare_frame.to_csv('target_test/json-to-csv.csv', sep=',', encoding='utf-8',index=False)

# %%
len(prepare_frame.index)
# Out:
# 8
